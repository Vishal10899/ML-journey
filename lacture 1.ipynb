# %%
import numpy as np

arr = np.array([
    [1,2,3],
    [4,5,6]
])

print("Array:")
print(arr)

print("Dimensions:", arr.ndim)
print("Shape:", arr.shape)
print("Size:", arr.size)
print("Datatype:", arr.dtype)
# Out:
# Array:
# [[1 2 3]
#  [4 5 6]]
# Dimensions: 2
# Shape: (2, 3)
# Size: 6
# Datatype: int64
