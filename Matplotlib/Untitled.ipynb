# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#create a df
x = np.linspace(0,5,11)
x
y = x**2
y

# %%
plt.plot(x,y)#import df as plt
plt.title('exp grph')# title
plt.xlabel('x axis')# labeling
plt.ylabel('y axis')

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,y)
plt.subplot(2,2,3)
plt.plot(x,x)
plt.subplot(2,2,4)
plt.plot(y,x)

# %%
df= sns.load_dataset('tips')
df

# %%
sns.histplot(df['total_bill'],bins = 20, kde=True)

# %%
# df.isnull().sum()
